# %%
import numpy as np
import pandas as pd

# %%
air = pd.read_csv('data/india_air_quality.csv')
# Out:
# /home/hanzhi/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3147: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
water = pd.read_csv('data/IndiaAffectedWaterQualityAreas.csv')

# %%
air['year'] = air['date'].str[:4]

# %%
air[['state','year','so2','no2','rspm','spm','pm2_5']]
# Out:
#                               state  year   so2   no2   rspm  spm  pm2_5
# 0                    Andhra Pradesh  1990   4.8  17.4    NaN  NaN    NaN
# 1                    Andhra Pradesh  1990   3.1   7.0    NaN  NaN    NaN
# 2                    Andhra Pradesh  1990   6.2  28.5    NaN  NaN    NaN
# 3                    Andhra Pradesh  1990   6.3  14.7    NaN  NaN    NaN
# 4                    Andhra Pradesh  1990   4.7   7.5    NaN  NaN    NaN
# ...                             ...   ...   ...   ...    ...  ...    ...
# 435737                  West Bengal  2015  22.0  50.0  143.0  NaN    NaN
# 435738                  West Bengal  2015  20.0  46.0  171.0  NaN    NaN
# 435739  andaman-and-nicobar-islands   NaN   NaN   NaN    NaN  NaN    NaN
# 435740                  Lakshadweep   NaN   NaN   NaN    NaN  NaN    NaN
# 435741                      Tripura   NaN   NaN   NaN    NaN  NaN    NaN
#
# [435742 rows x 7 columns]

# %%
air.head(1)['spm']
# Out:
# 0   NaN
# Name: spm, dtype: float64

# %%
air[air.spm != np.nan]
# Out:
#        stn_code       sampling_date                        state   location  \
# 0         150.0  February - M021990               Andhra Pradesh  Hyderabad
# 1         151.0  February - M021990               Andhra Pradesh  Hyderabad
# 2         152.0  February - M021990               Andhra Pradesh  Hyderabad
# 3         150.0     March - M031990               Andhra Pradesh  Hyderabad
# 4         151.0     March - M031990               Andhra Pradesh  Hyderabad
# ...         ...                 ...                          ...        ...
# 435737     SAMP            24-12-15                  West Bengal   ULUBERIA
# 435738     SAMP            29-12-15                  West Bengal   ULUBERIA
# 435739      NaN                 NaN  andaman-and-nicobar-islands        NaN
# 435740      NaN                 NaN                  Lakshadweep        NaN
# 435741      NaN                 NaN                      Tripura        NaN
#
#                                            agency  \
# ...

# %%
air.tail()
# Out:
#        stn_code sampling_date                        state  location  \
# 435737     SAMP      24-12-15                  West Bengal  ULUBERIA
# 435738     SAMP      29-12-15                  West Bengal  ULUBERIA
# 435739      NaN           NaN  andaman-and-nicobar-islands       NaN
# 435740      NaN           NaN                  Lakshadweep       NaN
# 435741      NaN           NaN                      Tripura       NaN
#
#                                            agency   type   so2   no2   rspm  \
# 435737  West Bengal State Pollution Control Board  RIRUO  22.0  50.0  143.0
# 435738  West Bengal State Pollution Control Board  RIRUO  20.0  46.0  171.0
# 435739                                        NaN    NaN   NaN   NaN    NaN
# 435740                                        NaN    NaN   NaN   NaN    NaN
# 435741                                        NaN    NaN   NaN   NaN    NaN
#
#         spm        location_monitoring_station  pm2_5        date  year
# ...

# %%
air.head()
# Out:
#   stn_code       sampling_date           state   location agency  \
# 0    150.0  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 1    151.0  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 2    152.0  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 3    150.0     March - M031990  Andhra Pradesh  Hyderabad    NaN
# 4    151.0     March - M031990  Andhra Pradesh  Hyderabad    NaN
#
#                                  type  so2   no2  rspm  spm  \
# 0  Residential, Rural and other Areas  4.8  17.4   NaN  NaN
# 1                     Industrial Area  3.1   7.0   NaN  NaN
# 2  Residential, Rural and other Areas  6.2  28.5   NaN  NaN
# 3  Residential, Rural and other Areas  6.3  14.7   NaN  NaN
# 4                     Industrial Area  4.7   7.5   NaN  NaN
#
#   location_monitoring_station  pm2_5        date  year
# 0                         NaN    NaN  1990-02-01  1990
# 1                         NaN    NaN  1990-02-01  1990
# ...

# %%
water.head(20)
# Out:
#         State Name           District                 Block  \
# 0   andhra pradesh  EAST GODAVARI(04)        PRATHIPADU(10)
# 1   andhra pradesh  EAST GODAVARI(04)        PRATHIPADU(10)
# 2   andhra pradesh  EAST GODAVARI(04)        PRATHIPADU(10)
# 3   andhra pradesh  EAST GODAVARI(04)        PRATHIPADU(10)
# 4   andhra pradesh  EAST GODAVARI(04)        PRATHIPADU(10)
# 5   andhra pradesh  EAST GODAVARI(04)        PRATHIPADU(10)
# 6   andhra pradesh  EAST GODAVARI(04)   RAMPACHODAVARAM(13)
# 7   andhra pradesh  EAST GODAVARI(04)        DEVIPATNAM(14)
# 8   andhra pradesh  EAST GODAVARI(04)            KADIAM(31)
# 9   andhra pradesh  EAST GODAVARI(04)            KADIAM(31)
# 10  andhra pradesh  EAST GODAVARI(04)            KADIAM(31)
# 11  andhra pradesh  EAST GODAVARI(04)            KADIAM(31)
# 12  andhra pradesh  EAST GODAVARI(04)            KADIAM(31)
# 13  andhra pradesh  EAST GODAVARI(04)  RAMACHANDRAPURAM(39)
# 14  andhra pradesh  WEST GODAVARI(05)           ACHANTA(41)
# ...

# %%
water.rename(columns = {'District Name': 'District', 'Block Name':'Block', 'Panchayat Name':'Panchayat',
       'Village Name':'Village', 'Habitation Name':'Habitation','Quality Parameter':'Contaminants'}, inplace = True)

# %%
water['State Name'] = water['State Name'].str.lower()

# %%
water.groupby('State Name').count()
# Out:
#                    District   Block  Panchayat  Village  Habitation  \
# State Name
# andhra pradesh         2888    2888       2888     2888        2888
# arunachal pradesh       612     612        612      612         612
# assam                 79910   79910      79910    79910       79910
# bihar                 92336   92336      92336    92336       92336
# chattisgarh           25062   25062      25062    25062       25062
# chhattisgarh           8815    8815       8815     8815        8815
# gujarat                2092    2092       2092     2092        2092
# haryana                 262     262        262      262         262
# himachal pradesh         88      88         88       88          88
# jammu and kashmir        67      67         67       67          67
# jharkhand              3913    3913       3913     3913        3913
# karnataka             30824   30824      30824    30824       30824
# kerala                 4800    4800       4800     4800        4800
# ...

# %%
state_water_contam = water.groupby(['State Name','Quality Parameter'])['Year'].count()

# %%
state_water_contam = pd.DataFrame(data = state_water_contam.values, index = state_water_contam.index, columns = ['contaminants'])

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ANDHRA PRADESH'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-90-fa504acab63a> in <module>
# ...
